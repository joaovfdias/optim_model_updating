# %%
from plotador_mo import *
from tests.indexador_2026 import *

# plotador da meta-opt

computador = 'LEST 1'
PC = indexar_device(computador)

param = 6

data_dir = os.path.join(PC.base_path, r"Problema 2\META-OPT", f"{param} PARAM")
save_dir = os.path.join(PC.base_path, r"Problema 2\Plotagens\Revisadas", f"{param} PARAM", "FINAIS")
os.makedirs(save_dir, exist_ok=True)

# %%
save_dir = False

# %% [markdown]
# BO

# %%
algo = "BO"
# save_dir = False

df_meta = pd.read_csv(os.path.join(data_dir, algo, f"meta_opt_{algo}.csv"))

limitar_eixo = {
    "EI": 0.0125
}

plotar_convergencia_bo(df_meta, ylim=limitar_eixo, salvar_em=save_dir)
plotar_sensibilidade_bo(df_meta, salvar_em=save_dir)
plotar_sensibilidade_bo_unificado(df_meta, salvar_em=save_dir)
# Out:
# [OK] Salvo: C:\Users\Thiago\OneDrive\Documentos\2025.2\Pesquisa\Rodadas\Problema 2\Plotagens\Revisadas\6 PARAM\FINAIS
# [OK] Salvo: C:\Users\Thiago\OneDrive\Documentos\2025.2\Pesquisa\Rodadas\Problema 2\Plotagens\Revisadas\6 PARAM\FINAIS
# [OK] Salvo: C:\Users\Thiago\OneDrive\Documentos\2025.2\Pesquisa\Rodadas\Problema 2\Plotagens\Revisadas\6 PARAM\FINAIS

# %% [markdown]
# GA / PSO

# %%
algo = "GA"
# save_dir = False
xticks = [2, 4]

df_meta = pd.read_csv(os.path.join(data_dir, algo, f"meta_opt_{algo}.csv"))

# plotar_aprendizado_pop(df_meta, xticks=xticks, salvar_em=save_dir)
plotar_mapa_calor_ga(df_meta, salvar_em=save_dir)

# plotar_correlacao_pop(df_meta, salvar_em=save_dir)
# Out:
# [OK] Salvo: C:\Users\Thiago\OneDrive\Documentos\2025.2\Pesquisa\Rodadas\Problema 2\Plotagens\Revisadas\6 PARAM\FINAIS

# %% [markdown]
# PSO

# %%
algo = "PSO"
# save_dir = False
xticks = [2, 4]

df_meta = pd.read_csv(os.path.join(data_dir, algo, f"meta_opt_{algo}.csv"))

# plotar_aprendizado_pop(df_meta, algo=algo, xticks=xticks, salvar_em=save_dir)
plotar_mapa_calor_pso_cognitivo_social(df_meta, salvar_em=save_dir)
plotar_mapa_calor_pso_inercia_atracao(df_meta, salvar_em=save_dir)

# plotar_correlacao_pop(df_meta, algo="PSO", salvar_em=save_dir)
# Out:
# [OK] Salvo: C:\Users\Thiago\OneDrive\Documentos\2025.2\Pesquisa\Rodadas\Problema 2\Plotagens\Revisadas\6 PARAM\FINAIS\Grafico_PSO_2_CognitivoSocial_20260724_155737.png
# [OK] Salvo: C:\Users\Thiago\OneDrive\Documentos\2025.2\Pesquisa\Rodadas\Problema 2\Plotagens\Revisadas\6 PARAM\FINAIS\Grafico_PSO_3_InerciaAtracao_20260724_155737.png
